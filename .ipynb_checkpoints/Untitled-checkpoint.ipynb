# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import statsmodels.api as sm 
import seaborn as sns 
sns.set()

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data.describe(include='all')
# Out:
#            Unnamed: 0             id  Gender   Customer Type            Age  \
# count   103904.000000  103904.000000  103904          103904  103904.000000
# unique            NaN            NaN       2               2            NaN
# top               NaN            NaN  Female  Loyal Customer            NaN
# freq              NaN            NaN   52727           84923            NaN
# mean     51951.500000   64924.210502     NaN             NaN      39.379706
# std      29994.645522   37463.812252     NaN             NaN      15.114964
# min          0.000000       1.000000     NaN             NaN       7.000000
# 25%      25975.750000   32533.750000     NaN             NaN      27.000000
# 50%      51951.500000   64856.500000     NaN             NaN      40.000000
# 75%      77927.250000   97368.250000     NaN             NaN      51.000000
# max     103903.000000  129880.000000     NaN             NaN      85.000000
#
# ...

# %% [markdown]
# #cleaning data

# %%
data_drop = data.drop(['id','Unnamed: 0'],axis=1)
data_drop.describe(include='all')
# Out:
#         Gender   Customer Type            Age   Type of Travel     Class  \
# count   103904          103904  103904.000000           103904    103904
# unique       2               2            NaN                2         3
# top     Female  Loyal Customer            NaN  Business travel  Business
# freq     52727           84923            NaN            71655     49665
# mean       NaN             NaN      39.379706              NaN       NaN
# std        NaN             NaN      15.114964              NaN       NaN
# min        NaN             NaN       7.000000              NaN       NaN
# 25%        NaN             NaN      27.000000              NaN       NaN
# 50%        NaN             NaN      40.000000              NaN       NaN
# 75%        NaN             NaN      51.000000              NaN       NaN
# max        NaN             NaN      85.000000              NaN       NaN
#
#         Flight Distance  Inflight wifi service  \
# ...

# %%
data_drop.shape
# Out:
# (103904, 23)

# %%
data_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %%
data_drop.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
arrival_delay_median = data_drop["Arrival Delay in Minutes"].median()
data_drop["Arrival Delay in Minutes"] = data_drop["Arrival Delay in Minutes"].fillna( value = arrival_delay_median)
data_no_mv = data_drop

# %%
data_no_mv.describe(include='all')
# Out:
#         Gender   Customer Type            Age   Type of Travel     Class  \
# count   103904          103904  103904.000000           103904    103904
# unique       2               2            NaN                2         3
# top     Female  Loyal Customer            NaN  Business travel  Business
# freq     52727           84923            NaN            71655     49665
# mean       NaN             NaN      39.379706              NaN       NaN
# std        NaN             NaN      15.114964              NaN       NaN
# min        NaN             NaN       7.000000              NaN       NaN
# 25%        NaN             NaN      27.000000              NaN       NaN
# 50%        NaN             NaN      40.000000              NaN       NaN
# 75%        NaN             NaN      51.000000              NaN       NaN
# max        NaN             NaN      85.000000              NaN       NaN
#
#         Flight Distance  Inflight wifi service  \
# ...

# %%
cols = ["Departure Delay in Minutes", "Arrival Delay in Minutes"]
fig, ax = plt.subplots(2, 1, figsize = (12, 8))
for i, column in enumerate(cols):
    sns.boxplot(data = data_no_mv, x = column,ax = ax[i])

# %%
sns.distplot(data_no_mv['Departure Delay in Minutes'])
# Out:
# C:\Users\salvi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Departure Delay in Minutes', ylabel='Density'>

# %%
sns.distplot(data_no_mv['Arrival Delay in Minutes'])
# Out:
# C:\Users\salvi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Arrival Delay in Minutes', ylabel='Density'>

# %%
data_no_mv[cols].skew()
# Out:
# Departure Delay in Minutes    6.733980
# Arrival Delay in Minutes      6.605288
# dtype: float64

# %%
Q1 = data_no_mv[cols].quantile(0.25)
Q3 = data_no_mv[cols].quantile(0.75)
IQR = Q3 - Q1
minimum=Q1 - 1.5 * IQR
maximum=Q3 + 1.5 * IQR
print(minimum)
print(maximum)
new_data = data_no_mv[data_no_mv['Departure Delay in Minutes'] < maximum[0]]
new_data = data_no_mv[data_no_mv['Arrival Delay in Minutes'] < maximum[1]]
new_data
# Out:
# Departure Delay in Minutes   -18.0
# Arrival Delay in Minutes     -19.5
# dtype: float64
# Departure Delay in Minutes    30.0
# Arrival Delay in Minutes      32.5
# dtype: float64
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# ...

# %% [markdown]
# After using IQR method

# %%
sns.distplot(data_no_mv['Departure Delay in Minutes'])
# Out:
# C:\Users\salvi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Departure Delay in Minutes', ylabel='Density'>

# %%
sns.distplot(data_no_mv['Arrival Delay in Minutes'])
# Out:
# C:\Users\salvi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Arrival Delay in Minutes', ylabel='Density'>

# %%
new_data.describe(include='all')
# Out:
#         Gender   Customer Type           Age   Type of Travel     Class  \
# count    89950           89950  89950.000000            89950     89950
# unique       2               2           NaN                2         3
# top     Female  Loyal Customer           NaN  Business travel  Business
# freq     45643           73580           NaN            61966     43281
# mean       NaN             NaN     39.428327              NaN       NaN
# std        NaN             NaN     15.121456              NaN       NaN
# min        NaN             NaN      7.000000              NaN       NaN
# 25%        NaN             NaN     27.000000              NaN       NaN
# 50%        NaN             NaN     40.000000              NaN       NaN
# 75%        NaN             NaN     51.000000              NaN       NaN
# max        NaN             NaN     85.000000              NaN       NaN
#
#         Flight Distance  Inflight wifi service  \
# count      89950.000000           89950.000000
# ...

# %%
sns.heatmap(data_no_mv.corr(),cmap='mako',center = 0)
# Out:
# <AxesSubplot:>

# %%
data_no_mv["satisfaction"].replace({"satisfied": 1, "neutral or dissatisfied": 0}, inplace = True)
data_no_mv.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
data_dummies = pd.get_dummies(data_no_mv,drop_first = True)
data_dummies.corr()['satisfaction'].sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# variables = new_data[['Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding',
#        'Seat comfort', 'Inflight entertainment', 'On-board service',
#        'Leg room service', 'Baggage handling', 'Checkin service',
#        'Inflight service', 'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes', 'satisfaction']]
# vif = pd.DataFrame()
# vif["Variance"] = [variance_inflation_factor(variables.values,i) for i in range(len(vif.columns))]
# vif["features"] = variables.columns

# %%
data_dummies_2 = pd.get_dummies(new_data)
data_dummies_2.columns
# Out:
# Index(['Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction', 'Gender_Female', 'Gender_Male',
#        'Customer Type_Loyal Customer', 'Customer Type_disloyal Customer',
#        'Type of Travel_Business travel', 'Type of Travel_Personal Travel',
#        'Class_Business', 'Class_Eco', 'Class_Eco Plus'],
#       dtype='object')

# %%
new_data.columns.values
# Out:
# array(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding',
#        'Seat comfort', 'Inflight entertainment', 'On-board service',
#        'Leg room service', 'Baggage handling', 'Checkin service',
#        'Inflight service', 'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes', 'satisfaction'], dtype=object)

# %%
sns.countplot(data = data_no_mv,x=new_data['Gender'],hue=data_no_mv['satisfaction'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.kdeplot(data= new_data,x= data_no_mv['Age'],fill=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data= data_no_mv,x= data_no_mv['Age'],hue = data_no_mv['satisfaction'],fill=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.countplot(data = data_no_mv,x=data_no_mv['Customer Type'],hue=data_no_mv['satisfaction'])
# Out:
# <AxesSubplot:xlabel='Customer Type', ylabel='count'>

# %%
sns.countplot(data = data_no_mv,x=data_no_mv['Class'],hue=data_no_mv['satisfaction'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
sns.barplot(data = data_no_mv,x=data_no_mv['Class'],hue=data_no_mv['satisfaction'],y=data_no_mv['Flight Distance'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Flight Distance'>

# %%
sns.countplot(data = data_no_mv,x=data_no_mv['Type of Travel'],hue=data_no_mv['satisfaction'])
# Out:
# <AxesSubplot:xlabel='Type of Travel', ylabel='count'>

# %%
sns.countplot(data = data_no_mv,x=data_no_mv['Type of Travel'],hue=data_no_mv['Customer Type'])
# Out:
# <AxesSubplot:xlabel='Type of Travel', ylabel='count'>

# %%
sns.countplot(data = data_no_mv,x=data_no_mv['Customer Type'],hue=data_no_mv['Class'])
# Out:
# <AxesSubplot:xlabel='Customer Type', ylabel='count'>

# %%
sns.scatterplot(x=data_no_mv['Departure Delay in Minutes'],y=data_no_mv['Arrival Delay in Minutes'],alpha=1)
# Out:
# <AxesSubplot:xlabel='Departure Delay in Minutes', ylabel='Arrival Delay in Minutes'>

# %% [markdown]
# as we can see that arrival delay in minutes and departure delay in minutes have strong coorelation

# %% [markdown]
# below we will see that how much services will affect the satisfaction of the customers

# %%
# services = ['Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness']

# fig, ax = plt.subplots(6, 2, figsize = (20, 55))

# for service in services:
#     sns.countplot(data = data_no_mv,x=service ,hue = data_no_mv['satisfaction'], ax = ax)
# plt.show()

#error for some reason
